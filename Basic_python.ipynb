# %% [markdown]
# <a href="https://colab.research.google.com/github/meghabothe996/PythonCode/blob/main/Basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this program adds two numbers
num1=99
num2=96
#add two numbers
sum=float(num1)+(num2)
#display the sum
print('The sum of{0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The sum of99 and 96 is 195.0

# %%
print(2+22)
# Out:
# 24

# %%
#this program subtract two numbers
num1=99
num2=96
#sub two numbers
sum=float(num1)-(num2)
#display the sub
print('The subtraction of{0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The subtraction of99 and 96 is 3.0

# %%
#this program print hello world
print('hello world')
# Out:
# hello world

# %%
#this program find area of square
side=3cm
#formula
area of square=side*2
#dispaly the area of square
area of square=3*2
# Out:
#   File "<ipython-input-11-dd6c5087132e>", line 2
#     side=3cm
#            ^
# SyntaxError: invalid syntax

# %%
print("Lesson 3: String Variable")
print('2+2')
print(2+2)
print('2'+'2')
name="MegHa Santosh Bothe"
print(name)
print(len(name))
print("Name:"+name)
print("hello".upper())
title="jdsfjk jdsf sjkdfh"
print(title.capitalize())
print(name.capitalize())
print(name.lower())
print(name.upper())
print("Name:"+name)
print("Name:%s" %name)
print("Name:{}". format(name))

print("slices")
print("good morning"[2:9])
print(name[2:6])

# %%
print("integer and float")
h=96
m=99
s=6.78
print(h)
print(m)
print(s)
print(h+m)
print(h*m)
print(m-h)
print(h/m)
print(h/s)
print(99+96)
print(99-96)
print("h is%s" %h)
print(100-99)

# %%
print("lesson 5: conditionalsp")
print("Does 3 equal 3?")
if 3==3:
   print(True)
a=33
b=99
if a<b:
  print("b is greater than a")
print("elif statement")

# %%
m=99
h=96
if h<m:
  print("m is greater than h")

# %%
player_a = "rock"
player_b = "rock"

if player_a == "rock" or player_b == "rock":
  print("Someone chose rock!")
  
if player-a == "rock" and player_b == "scissors":
  print("Player A wins!")
elif player_a == "rock" and player b_ == "paper":
  print("Player B wins!")
else:
  print("Tie!")

# %%
print("loop")

for x in range(0, 9):
print (x)

# %%
print(2+2)
